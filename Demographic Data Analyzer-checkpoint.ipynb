# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Gokul\Downloads\adult.csv\adult.csv', header=0)

# %%
df
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90         ?   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66         ?  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
df.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education.num   32561 non-null  int64
#  5   marital.status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital.gain    32561 non-null  int64
#  11  capital.loss    32561 non-null  int64
#  12  hours.per.week  32561 non-null  int64
#  13  native.country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.describe()
# Out:
#                 age        fnlwgt  education.num  capital.gain  capital.loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours.per.week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df.corr()
# Out:
#                      age    fnlwgt  education.num  capital.gain  capital.loss  \
# age             1.000000 -0.076646       0.036527      0.077674      0.057775
# fnlwgt         -0.076646  1.000000      -0.043195      0.000432     -0.010252
# education.num   0.036527 -0.043195       1.000000      0.122630      0.079923
# capital.gain    0.077674  0.000432       0.122630      1.000000     -0.031615
# capital.loss    0.057775 -0.010252       0.079923     -0.031615      1.000000
# hours.per.week  0.068756 -0.018768       0.148123      0.078409      0.054256
#
#                 hours.per.week
# age                   0.068756
# fnlwgt               -0.018768
# education.num         0.148123
# capital.gain          0.078409
# capital.loss          0.054256
# hours.per.week        1.000000

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education.num     0
# marital.status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# native.country    0
# income            0
# dtype: int64

# %%
df.shape
# Out:
# (32561, 15)

# %%
df2=df.replace(' ?',np.nan)
df2
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90         ?   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66         ?  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
# Question 1: How many people of each race are represented in this dataset?

race_counts = df['race'].value_counts

# %%
# Question 2: What is the average age of men?

avg_age_men = df[df['sex'] == 'Male']['age'].mean()

# %%
#Question 3: What is the percentage of people who have a Bachelor's degree?

percentage_people = (df[df['education'] == 'Bachelors'].shape[0]/ df.shape[0]) *100

# %%
#Question 4:What percentage of people with advanced education make more than 50K?

advanced_education = (df[df['education'].isin(['Bachelors', 'Masters', 'Doctorate'])])

percentage_advanced_education = (advanced_education[advanced_education['income'] == '>50K'].shape[0] / advanced_education.shape[0]) *100

# %%
advanced_education[advanced_education['income'] == '>50K'].shape[0]
# Out:
# 3486

# %%
advanced_education.shape[0]
# Out:
# 7491

# %%
# Question 5: What percentage of people without advanced education make more than 50K?

no_advanced_education = df[~df['education'].isin(['Bachelors', 'Masters', 'Doctorate'])]

percentage_no_advanced_education = (no_advanced_education[no_advanced_education['income'] == '>50K'].shape[0] / no_advanced_education.shape[0]) *100

# %%
#Question 6: What is the minimum number of hours a person works per week?

min_hrs_work = df['hours.per.week'].min()

# %%
 #Question 7: What percentage of the people who work the minimum number of hours per week have a salary of more than 50K?
    
num_min_workers= df[df['hours.per.week'] == min_hrs_work]
percentage_min_hrs_work =(num_min_workers[num_min_workers ['income'] == '>50K'].shape[0] / num_min_workers .shape[0]) * 100

# %%
# Question 8: What country has the highest percentage of people that earn >50K and what is that percentage?
highest_earning_country = df[df['income'] == '>50K']['native.country'].value_counts(normalize=True).idxmax()
highest_earning_percentage = (df[(df['native.country'] == highest_earning_country) & (df['income'] == '>50K')].shape[0] / df[df['native.country'] == highest_earning_country].shape[0]) * 100

# %%
# Question 9: Identify the most popular occupation for those who earn >50K in India.

df[df['native.country'] == 'India']
# Out:
#        age     workclass  fnlwgt    education  education.num  \
# 90      39       Private  198654  Prof-school             15
# 214     42  Self-emp-inc   23510      Masters             14
# 710     42       Private  198341      Masters             14
# 887     23       Private  143003      Masters             14
# 1330    55       Private  135803    Bachelors             13
# ...    ...           ...     ...          ...            ...
# 30103   32       Private   79586    Bachelors             13
# 30431   41   Federal-gov  219155  Prof-school             15
# 30466   48       Private  119471    Doctorate             16
# 31050   25       Private  110978   Assoc-acdm             12
# 31081   26       Private  160261      Masters             14
#
#            marital.status       occupation   relationship                race  \
# 90     Married-civ-spouse   Prof-specialty        Husband  Asian-Pac-Islander
# ...

# %%
top_IN_occupation = df[(df['native.country'] == 'India') & (df['income'] == '>50K')]['occupation'].value_counts().idxmax()

# %%
print("Question 1:")
print(race_counts)
# Out:
# Question 1:
# <bound method IndexOpsMixin.value_counts of 0        White
# 1        White
# 2        Black
# 3        White
# 4        White
#          ...
# 32556    White
# 32557    White
# 32558    White
# 32559    White
# 32560    White
# Name: race, Length: 32561, dtype: object>

# %%
print("\nQuestion 2:")
print(round(avg_age_men, 1))
# Out:
# Question 2:
# 39.4

# %%
print("\nQuestion 3:")
print(round(percentage_people,1))
# Out:
# Question 3:
# 16.4

# %%
print("\nQuestion 4:")
print(round(percentage_advanced_education,1))
# Out:
# Question 4:
# 46.5

# %%
print("\nQuestion 5:")
print(round(percentage_no_advanced_education,1))
# Out:
# Question 5:
# 17.4

# %%
print("Question 6:")
print(min_hrs_work)
# Out:
# Question 6:
# 1

# %%
print("Question 7:")
print(percentage_min_hrs_work)
# Out:
# Question 7:
# 10.0

# %%
print("\nQuestion 8:")
print(round(highest_earning_percentage,1))
# Out:
# Question 8:
# 24.6

# %%
print("Question 9:")
print(top_IN_occupation)
# Out:
# Question 9:
# Prof-specialty
